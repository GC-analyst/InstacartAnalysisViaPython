# %% [markdown]
# ### Importing Libraries and Data

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# creating data path to '02 Data'
datapath = r'/Users/gabrielconfrey/Desktop/Data Analysis/Career Foundry/Achievement 4/082023 Instacart Basket Analysis/02 Data'

# %%
# Importing df_orders_prior
df_orders_prior = pd.read_csv(os.path.join(datapath, '1 Original Data', '4.6 Data Download', 'orders_products_prior.csv'), index_col = False)

# %%
# Importing latest orders file
df_orders = pd.read_csv(os.path.join(datapath, '2 Prepared Data', 'orders_checked.csv'), index_col = False)

# %% [markdown]
# ### Checking both dfs output

# %%
df_orders.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           1   2398795        1    prior             2                   3
# 2           2    473747        1    prior             3                   3
# 3           3   2254736        1    prior             4                   4
# 4           4    431534        1    prior             5                   4
#
#    time_of_order  days_since_prior_order
# 0              8                     7.0
# 1              7                    15.0
# 2             12                    21.0
# 3              7                    29.0
# 4             15                    28.0

# %% [markdown]
# #### Dropping 'Unnamed: 0' to return 'eval_set' because it bugs me.

# %%
df_orders.drop(['Unnamed: 0'], axis=1)
# Out:
#          order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0         2539329        1    prior             1                   2
# 1         2398795        1    prior             2                   3
# 2          473747        1    prior             3                   3
# 3         2254736        1    prior             4                   4
# 4          431534        1    prior             5                   4
# ...           ...      ...      ...           ...                 ...
# 3421078   2266710   206209    prior            10                   5
# 3421079   1854736   206209    prior            11                   4
# 3421080    626363   206209    prior            12                   1
# 3421081   2977660   206209    prior            13                   1
# 3421082    272231   206209    train            14                   6
#
#          time_of_order  days_since_prior_order
# 0                    8                     7.0
# ...

# %%
df_orders_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_orders_prior.shape
# Out:
# (32434489, 4)

# %%
### Combining dataframes with df.merge()
df_orders_merged = df_orders.merge(df_orders_prior, on = 'order_id', indicator = True)

# %%
df_orders_merged.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           0   2539329        1    prior             1                   2
# 2           0   2539329        1    prior             1                   2
# 3           0   2539329        1    prior             1                   2
# 4           0   2539329        1    prior             1                   2
#
#    time_of_order  days_since_prior_order  product_id  add_to_cart_order  \
# 0              8                     7.0         196                  1
# 1              8                     7.0       14084                  2
# 2              8                     7.0       12427                  3
# 3              8                     7.0       26088                  4
# 4              8                     7.0       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# ...

# %%
df_orders_merged['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# ### We can pickle that

# %%
# Export data to pkl
df_orders_merged.to_pickle(os.path.join(datapath, '2 Prepared Data', 'orders_products_combined.pkl'))

# %% [markdown]
# ## TASK 4.6

# %% [markdown]
# ### 3) In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.

# %%
# Import orders_products_combined
df_ord = pd.read_pickle(os.path.join(datapath, '2 Prepared Data', 'orders_products_combined.pkl'))

# %%
df_ord.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           0   2539329        1    prior             1                   2
# 2           0   2539329        1    prior             1                   2
# 3           0   2539329        1    prior             1                   2
# 4           0   2539329        1    prior             1                   2
#
#    time_of_order  days_since_prior_order  product_id  add_to_cart_order  \
# 0              8                     7.0         196                  1
# 1              8                     7.0       14084                  2
# 2              8                     7.0       12427                  3
# 3              8                     7.0       26088                  4
# 4              8                     7.0       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# ...

# %%
df_ord.drop(['Unnamed: 0'], axis=1)
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2539329        1    prior             1                   2
# 2          2539329        1    prior             1                   2
# 3          2539329        1    prior             1                   2
# 4          2539329        1    prior             1                   2
# ...            ...      ...      ...           ...                 ...
# 32434484   2977660   206209    prior            13                   1
# 32434485   2977660   206209    prior            13                   1
# 32434486   2977660   206209    prior            13                   1
# 32434487   2977660   206209    prior            13                   1
# 32434488   2977660   206209    prior            13                   1
#
#           time_of_order  days_since_prior_order  product_id  \
# ...

# %%
df_orders_final = df_ord.drop(['Unnamed: 0'], axis=1)

# %%
df_orders_final.shape
# Out:
# (32434489, 11)

# %% [markdown]
# ### 5) Determine a suitable way to combine the orders_products_combined dataframe with your products data set. Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %%
# Import Products Data
df_products = pd.read_csv(os.path.join(datapath, '2 Prepared Data', 'product_checked.csv'), index_col = False)

# %%
df_products.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %% [markdown]
# #### Both dfs have 'product_id' in common, which can be used as ON.

# %% [markdown]
# ### 6) Confirm the results of the merge using the merge flag.

# %%
# Testing merging product and orders dfs
pd.merge(df_orders_final, df_products, on = 'product_id')
# Out:
#           order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0          2539329        1    prior             1                   2
# 1          2398795        1    prior             2                   3
# 2           473747        1    prior             3                   3
# 3          2254736        1    prior             4                   4
# 4           431534        1    prior             5                   4
# ...            ...      ...      ...           ...                 ...
# 32404854   1320836   202557    prior            17                   2
# 32404855     31526   202557    prior            18                   5
# 32404856    758936   203436    prior             1                   2
# 32404857   2745165   203436    prior             2                   3
# 32404858   3093936   205420    prior             1                   4
#
#           time_of_order  days_since_prior_order  product_id  \
# ...

# %%
# Dropping _merge column from df_orders_final
df_ord_finfin = df_orders_final.drop(['_merge'], axis=1)

# %%
# Merging all dfs AS df_merged
df_merged = df_ord_finfin.merge(df_products, on = 'product_id', indicator = True)

# %%
df_merged.shape
# Out:
# (32404859, 16)

# %%
df_merged.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    time_of_order  days_since_prior_order  product_id  add_to_cart_order  \
# 0              8                     7.0         196                  1
# 1              7                    15.0         196                  1
# 2             12                    21.0         196                  1
# 3              7                    29.0         196                  1
# 4             15                    28.0         196                  1
#
#    reordered  Unnamed: 0 product_name  aisle_id  department_id  prices _merge
# ...

# %% [markdown]
# #### Checking value counts for merge

# %%
df_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# ### 7) Export the newly created dataframe as orders_products_merged in a suitable format (taking into consideration the size). (Exporing as pickle due to large size of merged df)

# %%
# Export data to pkl
df_merged.to_pickle(os.path.join(datapath, '2 Prepared Data', 'order_merged.pkl'))
