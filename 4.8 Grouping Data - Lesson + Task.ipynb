# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# creating data path to '02 Data'
datapath = r'/Users/gabrielconfrey/Desktop/Data Analysis/Career Foundry/Achievement 4/082023 Instacart Basket Analysis/02 Data'

# %%
# Importing df 48_cleaned from 4.7
ords_prods_merge = pd.read_pickle(os.path.join(datapath, '2 Prepared Data', '48_cleaned.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  time_of_order  \
# 0   2539329        1             1                   2              8
# 1   2398795        1             2                   3              7
# 2    473747        1             3                   3             12
# 3   2254736        1             4                   4              7
# 4    431534        1             5                   4             15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices price_range_loc  \
# ...

# %% [markdown]
# #### Create subset

# %%
df_sm = ords_prods_merge[:1000000]

# %% [markdown]
# #### Checking 1 - head, 2 - shape (ALWAYS)

# %%
df_sm.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  time_of_order  \
# 0   2539329        1             1                   2              8
# 1   2398795        1             2                   3              7
# 2    473747        1             3                   3             12
# 3   2254736        1             4                   4              7
# 4    431534        1             5                   4             15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices price_range_loc  \
# ...

# %%
df_sm.shape
# Out:
# (1000000, 19)

# %% [markdown]
# #### Doing first df.groupby() - won't show output!

# %%
df_sm.groupby('product_name')

# %% [markdown]
# ### Aggregating in Python is done by using the appropriately named agg() function. Let’s see how you might use this function to produce a single descriptive statistic for the “order_number” column. If you were to calculate the mean of the “order_number” column grouped by the “department_id” column, you could quickly compare the average number of orders per user across each Instacart department. (Recall that “order_number” refers to the number of orders placed by a given user.) This will involve two of the steps in the three-step process introduced above:
#
# #### Split the data into groups based on “department_id.” Apply the agg() function to each group to obtain the mean values for the “order_number” column.

# %%
df_sm.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 4                18.825780
# 7                17.472355
# 13               17.993423
# 14               19.246334
# 16               19.463012
# 17               11.294069
# 19               19.305237
# 20               17.599636

# %%
# Alternative function
df_sm.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 4     18.825780
# 7     17.472355
# 13    17.993423
# 14    19.246334
# 16    19.463012
# 17    11.294069
# 19    19.305237
# 20    17.599636
# Name: order_number, dtype: float64

# %%
# Multiple aggregations simultaneously
df_sm.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 4                18.825780   1  99
# 7                17.472355   1  99
# 13               17.993423   1  99
# 14               19.246334   1  99
# 16               19.463012   1  99
# 17               11.294069   1  98
# 19               19.305237   1  99
# 20               17.599636   1  99

# %% [markdown]
# ### Creating loyalty flag
# #### First, a new column called “max_order” is created, which will be what stores the maximum order number for each user (step 3). Then, the ords_prods_merge dataframe is grouped by the “user_id” column (step 1). And finally, the transform() function is applied on the “order_number” column with the np.max argument (step 2).

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %% [markdown]
# #### But what is this np? This is actually the NumPy library! Remember the import code you include at the beginning of every notebook? In that code, you assigned the NumPy library to the np variable. Now, you’re finally going to use that variable. The max() function is a function included within NumPy that finds the max value within a column. Including this as an argument within the transform() function tells Python to “transform the ‘order_number’ column by applying the max() function from the NumPy library.”

# %%
ords_prods_merge.head(25)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  time_of_order  \
# 0    2539329        1             1                   2              8
# 1    2398795        1             2                   3              7
# 2     473747        1             3                   3             12
# 3    2254736        1             4                   4              7
# 4     431534        1             5                   4             15
# 5    3367565        1             6                   2              7
# 6     550135        1             7                   1              9
# 7    3108588        1             8                   1             14
# 8    2295261        1             9                   1             16
# 9    2550362        1            10                   4              8
# 10   2968173       15            15                   1              9
# 11   1870022       15            17                   2             16
# ...

# %%
# Using loc() to create 'loyalty_tag' column
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge.head(5)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  time_of_order  \
# 0   2539329        1             1                   2              8
# 1   2398795        1             2                   3              7
# 2    473747        1             3                   3             12
# 3   2254736        1             4                   4              7
# 4    431534        1             5                   4             15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0  ... aisle_id  department_id  prices  price_range_loc  \
# ...

# %%
# To see only a few columns worth of head
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10
# ...

# %% [markdown]
# # TASK 4.8 START

# %% [markdown]
# ### 2) In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe. (ENTIRE df just means, NOT the subset - not every column)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  time_of_order  \
# 0   2539329        1             1                   2              8
# 1   2398795        1             2                   3              7
# 2    473747        1             3                   3             12
# 3   2254736        1             4                   4              7
# 4    431534        1             5                   4             15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0  ... aisle_id  department_id  prices  price_range_loc  \
# ...

# %%
# Finding mean of all columns, grouped by "department_id"
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### 3) Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
# #### There are significantly more department ids, with much higher mean values, than there were in the subset.

# %% [markdown]
# ### 4) Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %%
# Completed during lesson. Copy/pasted here:
# To see only a few columns worth of head
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(20)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             2
# 2         1      New customer             3
# 3         1      New customer             4
# 4         1      New customer             5
# 5         1      New customer             6
# 6         1      New customer             7
# 7         1      New customer             8
# 8         1      New customer             9
# 9         1      New customer            10
# 10       15  Regular customer            15
# 11       15  Regular customer            17
# 12       15  Regular customer            18
# 13       15  Regular customer            21
# 14       15  Regular customer            22
# 15       19      New customer             2
# 16       19      New customer             5
# 17       19      New customer             7
# 18       21  Regular customer            10
# 19       31  Regular customer            10

# %%
# Displaying value counts:
ords_prods_merge['loyalty_flag'].value_counts()
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %% [markdown]
# ### 5) The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
# Multiple aggregations simultaneously
ords_prods_merge.groupby('loyalty_flag').agg({'prices': ['mean', 'sum', 'min', 'max']})
# Out:
#                      prices
#                        mean          sum  min      max
# loyalty_flag
# Loyal customer    10.386336  106814042.2  1.0  99999.0
# New customer      13.294670   83011787.2  1.0  99999.0
# Regular customer  12.495717  198391693.2  1.0  99999.0

# %% [markdown]
# #### Interestingly, Loyal customers have the lowest average price, and only half the total of the Regular customers. New customers have the highest average price, but the lowest total. The Min/Max for each is the same due to engineering settings.

# %% [markdown]
# ### 6) The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
# #### If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
# #### If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# Using loc() to create 'spending_flag' column
ords_prods_merge.loc[ords_prods_merge['prices'] >= 10, 'spending_flag'] = 'High spender'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] < 10, 'spending_flag'] = 'Low spender'

# %%
ords_prods_merge.head(5)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  time_of_order  \
# 0   2539329        1             1                   2              8
# 1   2398795        1             2                   3              7
# 2    473747        1             3                   3             12
# 3   2254736        1             4                   4              7
# 4    431534        1             5                   4             15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0  ... department_id  prices  price_range_loc  traffic_level  \
# ...

# %%
ords_prods_merge['spending_flag'].value_counts()
# Out:
# spending_flag
# Low spender     21760937
# High spender    10643922
# Name: count, dtype: int64

# %% [markdown]
# ### 7) In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
# #### If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
# #### If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
# #### If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %%
# Creating “median_ord_time” column

ords_prods_merge['median_ord_time'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
ords_prods_merge.head(1)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  time_of_order  \
# 0   2539329        1             1                   2              8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     7.0         196                  1          0
#
#    Unnamed: 0  ... prices  price_range_loc  traffic_level  traffic_level2  \
# 0         195  ...    9.0        Mid-range         Normal          Normal
#
#   busiest_times busiest_period_of_day max_order  loyalty_flag spending_flag  \
# 0       Average               Average        10  New customer   Low spender
#
#    median_ord_time
# 0             20.0
#
# [1 rows x 23 columns]

# %%
# Create tags for "median_ord_time" flag of >20, <=20 & >10, <=10
ords_prods_merge.loc[ords_prods_merge['median_ord_time'] > 20, 'prior_order_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_ord_time'] <= 20) & (ords_prods_merge['median_ord_time'] > 10), 'prior_order_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_ord_time'] <= 10, 'prior_order_flag'] = 'Frequent customer'

# %%
ords_prods_merge.head(50)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  time_of_order  \
# 0    2539329        1             1                   2              8
# 1    2398795        1             2                   3              7
# 2     473747        1             3                   3             12
# 3    2254736        1             4                   4              7
# 4     431534        1             5                   4             15
# 5    3367565        1             6                   2              7
# 6     550135        1             7                   1              9
# 7    3108588        1             8                   1             14
# 8    2295261        1             9                   1             16
# 9    2550362        1            10                   4              8
# 10   2968173       15            15                   1              9
# 11   1870022       15            17                   2             16
# ...

# %%
ords_prods_merge['prior_order_flag'].value_counts()
# Out:
# prior_order_flag
# Frequent customer        22790523
# Regular customer          6927608
# Non-frequent customer     2686728
# Name: count, dtype: int64

# %%
# Exporting new df as pkl
ords_prods_merge.to_pickle(os.path.join(datapath, '2 Prepared Data', '49_flagged.pkl'))
